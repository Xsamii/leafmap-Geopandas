# %%
import leafmap .foliumap as leafmap
import streamlit as st
import geopandas as gpd

# %% [markdown]
# ## creating the map

# %%
m = leafmap.Map()
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## changing the map to other basemap

# %%
apikey = "AIzaSyDoKwrfCjQ3OqgvJNtoynhNIt8AHpWgUrc"
m.add_tile_layer(
    url=f"https://mt1.google.com/vt/lyrs=m&x={{x}}&y={{y}}&z={{z}}&key={apikey}",
    name="Google Satellite",
    attribution="Google",
)

m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## reading with geopandas

# %%
file= gpd.read_file("Samples.geojson")
file
# Out:
# 2023-03-19 16:58:26.641 PROJ: proj_create: no database context specified
# 2023-03-19 16:58:26.708 PROJ: proj_identify: C:\Program Files\PostgreSQL\15\share\contrib\postgis-3.3\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 0 whereas a number >= 2 is expected. It comes from another PROJ installation.
#                               SITE_NAME           BASIN_NAME  ELEVATION  \
# 0                      El Capitan Beach  South Central Coast       24.0
# 1                Fresno-Drummond Street   San Joaquin Valley       89.0
# 2             San Diego-Overland Avenue            San Diego      135.0
# 3         Ventura-Emma Wood State Beach  South Central Coast        3.0
# 4               Visalia-N Church Street   San Joaquin Valley       97.0
# ..                                  ...                  ...        ...
# 162        Pico Rivera-4144 San Gabriel          South Coast       75.0
# 163          King City-415 Pearl Street  North Central Coast        6.0
# ...

# %% [markdown]
# ## transfer tp GeoDataFrame

# %%
gdf = gpd.GeoDataFrame(file)
# gdf = gdf.to_crs(3875)
gdf
# Out:
#                               SITE_NAME           BASIN_NAME  ELEVATION  \
# 0                      El Capitan Beach  South Central Coast       24.0
# 1                Fresno-Drummond Street   San Joaquin Valley       89.0
# 2             San Diego-Overland Avenue            San Diego      135.0
# 3         Ventura-Emma Wood State Beach  South Central Coast        3.0
# 4               Visalia-N Church Street   San Joaquin Valley       97.0
# ..                                  ...                  ...        ...
# 162        Pico Rivera-4144 San Gabriel          South Coast       75.0
# 163          King City-415 Pearl Street  North Central Coast        6.0
# 164  Carrizo Plains School-9640 Carrizo  South Central Coast      677.0
# 165                       Tracy-Airport   San Joaquin Valley       30.0
# 166           Joshua Tree National Park           Salton Sea      984.0
#
#      OZONE                             geometry
# 0    0.045    POINT (-2388.53320 -394881.93050)
# ...
